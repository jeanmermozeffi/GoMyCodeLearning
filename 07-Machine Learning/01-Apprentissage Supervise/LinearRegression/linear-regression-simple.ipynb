# %% [markdown]
# ### importation des bibliothèques et packages

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
# extract x and y from our data
# Extraction de la Variable Indépendante 𝑥
X = data["Age"].values[:, np.newaxis]

# Extraction de la Variable Dépendante 𝑦
y = data["Salary"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=40) #splitting data with test size of 35%

# %%
model = LinearRegression()   # Build linear regression model

# %%
model.fit(X_train, y_train)  #fitting the training data

# %% [markdown]
# 1. Intialisation
# 2. Propagation Avant
# 3. Calcul de la Perte
# 4. Rétropropagation et mise à jour des paramètres
# 5. Itération
#     - 2, 3, 4

# %%
predicted = model.predict(X_test) #testing our model’s performance

# %%
print("MSE", mean_squared_error(y_test, predicted))
print("R squared", metrics.r2_score(y_test, predicted))

# %% [markdown]
# #### Application

# %%
X = np.array([[25], [30], [35], [40], [45], [50], [55], [60], [65], [70]])
y = np.array([50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
X_train

# %%
X_test

# %%
model = LinearRegression()
model.fit(X_train, y_train)

# %%
predicted = model.predict(X_test)
print("Predicted", predicted)

# %%
## Évaluation de la Performance
mse = mean_squared_error(y_test, predicted)
r2 = metrics.r2_score(y_test, predicted)

print("MSE", mse)
print("R squared", r2)

# %%
# Nouvelle Donnée

ages = np.array([[70], [85]])

predicted_ages = model.predict(ages)

print("Salaire Estime", predicted_ages)

# %%
model.predict(np.array([[20]]))

# %%
model.predict(np.array([[18]]))

# %%
model.predict(np.array([[51]]))

# %% [markdown]
# # Visualisation des Résultats
# Visualisez les résultats pour mieux comprendre la performance du modèle.

# %%
plt.scatter(X_test, y_test, color="black", label="Données Réelles")
plt.plot(X_test, predicted, color="blue", linewidth=2, label="Prédictions")
plt.xlabel("Caractéristiques")
plt.ylabel("Target")
plt.title("Estimation du Salaire en fonction de l'âge")
plt.legend()
plt.show()

# %%
predicted
